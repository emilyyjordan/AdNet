# %%
#changing the deck probabilities
#have decays in deck A and B -- play with coefficient that determines the temporal relationship
#eventually want to run a loop so that we can generate decks with different decay coefficients
#make deck code into a function that returns the decks

# %%
import random
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#original code for decks

#PLOTS

random.seed(10)
myT = []

count1 = 1
count2 = 1
while count1 <= 50 or count2 <= 50:
    choice = np.random.randint(0,2)
    print(choice)
    if choice == 0 and count1 <= 50:
        count1 += 1
        myT.append(0)
        print("while loop 1")

    if choice == 1 and count2 <= 50:
        count2 += 1
        myT.append(1)
        print("while loop 2")
# Out:
# 1
# while loop 2
# 1
# while loop 2
# 0
# while loop 1
# 1
# while loop 2
# 0
# while loop 1
# 0
# while loop 1
# 0
# while loop 1
# 1
# while loop 2
# 0
# while loop 1
# 1
# while loop 2
# 0
# while loop 1
# 0
# while loop 1
# 0
# while loop 1
# 0
# while loop 1
# 1
# while loop 2
# 0
# while loop 1
# 1
# while loop 2
# 1
# while loop 2
# 0
# while loop 1
# 1
# while loop 2
# 1
# while loop 2
# 1
# while loop 2
# 0
# while loop 1
# 1
# while loop 2
# 1
# while loop 2
# 0
# while loop 1
# 1
# while loop 2
# 1
# while loop 2
# 1
# while loop 2
# 1
# while loop 2
# 0
# while loop 1
# 0
# while loop 1
# 1
# while loop 2
# 1
# while loop 2
# 0
# while loop 1
# 0
# while loop 1
# 0
# while loop 1
# 0
# while loop 1
# 0
# while loop 1
# 0
# while loop 1
# 1
# while loop 2
# 1
# while loop 2
# 1
# while loop 2
# 0
# while loop 1
# 1
# while loop 2
# 1
# while loop 2
# 1
# while loop 2
# 0
# while loop 1
# 0
# while loop 1
# 0
# while loop 1
# 1
# while loop 2
# 1
# while loop 2
# 1
# while loop 2
# 0
# while loop 1
# 1
# while loop 2
# 0
# while loop 1
# 1
# while loop 2
# 0
# while loop 1
# 0
# while loop 1
# 0
# while loop 1
# 0
# while loop 1
# 0
# while loop 1
# 0
# while loop 1
# 1
# while loop 2
# 1
# while loop 2
# 1
# while loop 2
# 1
# while loop 2
# 1
# while loop 2
# 0
# while loop 1
# 1
# while loop 2
# 0
# while loop 1
# 1
# while loop 2
# 1
# while loop 2
# 1
# while loop 2
# 0
# while loop 1
# 0
# while loop 1
# 0
# while loop 1
# 0
# while loop 1
# 0
# while loop 1
# 0
# while loop 1
# 0
# while loop 1
# 0
# while loop 1
# 0
# while loop 1
# 1
# while loop 2
# 0
# while loop 1
# 1
# while loop 2
# 1
# while loop 2
# 1
# while loop 2
# 1
# while loop 2
# 0
# while loop 1
# 0
# while loop 1
# 1
# while loop 2
# 0
# while loop 1
# 1
# while loop 2
# 0
# while loop 1
# 0
# while loop 1
# 1
# while loop 2
# 0
# 0
# 1
# while loop 2
# 1
# while loop 2
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 1
# while loop 2

# %%
def buildDecks(base, currCard_num, logpart, idk, intercept,):
    wholeDeckA = []
    for i in range(1, 101):
        t = myT[i-1]
        err = np.random.normal(0,5)
        if t == 1:
            currCard = base + err
            wholeDeckA.append(currCard)
        else:
            currCard = (currCard_num/(math.log((logpart), idk)))+intercept
            wholeDeckA.append(currCard)
        wholeDeckA = [(5 * round(logpart)) for i in wholeDeckA]
buildDecks(-15, 2000, (i+5), 1.1, -40)

plt.scatter(range(len(wholeDeckA)), wholeDeckA, color = "#3778bf")
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.show()

# %%
#ORIGINAL CODE!


#deck A - addictive
wholeDeckA = []
for i in range(1, 101):
    t = myT[i-1]
    err = np.random.normal(0,5)
    if t == 1:
        currCard = -15 + err
        wholeDeckA.append(currCard)
    else:
        currCard =(2000/(math.log((i+5), 1.1)))-40
        wholeDeckA.append(currCard)

wholeDeckA = [(5 * round(i/5)) for i in wholeDeckA]

plt.scatter(range(len(wholeDeckA)), wholeDeckA, color = "#3778bf")
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.show()

#deck B - non-addictive
wholeDeckB = []
for i in range(100):
    t = myT[i]
    err = np.random.normal(0, 5)
    if t == 1:
        currCard = 15 + err
        wholeDeckB.append(currCard)
    else:
        currCard =(-2000/(math.log((i+5), 1.1)))+40
        wholeDeckB.append(currCard)
        
wholeDeckB = [(5 * round(i/5)) for i in wholeDeckB]
plt.scatter(range(len(wholeDeckB)), wholeDeckB, color = "#feb308") #yellow
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.show()

#deck C - control
wholeDeckC = []
for i in range(100):
    t = myT[i]
    err = np.random.normal(0, 5)
    if t == 1:
        currCard = 15 + err
        wholeDeckC.append(currCard)
    else:
        currCard = -15 + err
        wholeDeckC.append(currCard)

wholeDeckC = [(5 * round(i/5)) for i in wholeDeckC]

plt.scatter(range(len(wholeDeckC)), wholeDeckC, color = "#3778bf")
plt.scatter(range(len(wholeDeckC)), wholeDeckC, color = "#9b59b6")
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.show()

print(np.sum(wholeDeckA))
print(np.sum(wholeDeckB))
print(np.sum(wholeDeckC))
# Out:
# -110
# 15
# 130
